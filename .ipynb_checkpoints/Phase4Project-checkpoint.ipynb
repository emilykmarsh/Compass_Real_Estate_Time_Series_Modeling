# %% [markdown]
# # Zillow Data Time Series Analysis

# %% [markdown]
#  - Emily Marsh
#  - Self Paced
#  - Scheduled Project Review Date/Time:
#  - Instructor Name: Morgan Jones

# %% [markdown]
# # Introduction

# %% [markdown]
# In the United States, a common investment oppurtunity for personal and commercial investment is real estate. In 2023 the average the average annual return on investment for residential real estate in the United States is 10.6 percent. Commercial real estate averages a slightly lower ROI of 9.5 percent, while REITs average a slightly higher 11.8 percent. There have been recent historical events that have had an impact on this annual return on investment. The housing crash in 2011 as well as the COVID pandemic of 2020 have had outsized impacts on pricing of housing, however a consistent increase over time has made this an area of consistent profits. Compass Real Estate, an real estate brokerage company that specializes in high-margin, luxury homes in upscale markets, has commissioned this project to expand into a new lower cost housing market in order to appeal to a broader group of clients and quicker cash flow.

# %% [markdown]
# ## Business Objective

# %% [markdown]
# Compass Real Estate is interested in investing in lower priced housing, under $300,000, for a smaller but more consistent revenue stream to supplement their luxury housing investments. This will also give the company the chance to expand their client base to more middle class home buyers. However, before investing capitol in this new venture, Compass would like to do analysis into determining the best five zipcodes that provides the biggest chance of profit. Using the dataset, this analysis will provide insight into the five best zip codes for investment as well as the projected profits over the next five years in each zip code. These predication will be made using Time Series modeling.

# %% [markdown]
# ## Dataset

# %% [markdown]
# The dataset used for this project is a subset of a larger dataset from Zillow, and consists of **14,732 rows** and **272 columns**. The format of the dataset includes features about **RegionID, Region Name (Zipcode), City, State, Metro, County Name, Size Rank**, and the **average price of houses in the zipcode starting in April of 1994 and ending with April of 2018**. Each **RegionName/Zipcode** is a unique value, while **Metro and County Name** are not. It is also important to note that the dataset is in a **wide format** versus a **long format**. Therefore in order to pass this data into an ARIMA model, the dataset will need to be reshaped to a **long format**.

# %% [markdown]
# ## Import Libraries

# %%
#Importing necessary Packages

import warnings
import itertools
import numpy as np
import pandas as pd
import statsmodels.api as sm
from collections import Counter
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pylab import rcParams
# %matplotlib inline
import geopandas as gpd
import seaborn as sns
from geopandas import GeoDataFrame
from shapely.geometry import Point, Polygon


warnings.filterwarnings('ignore')

# %% [markdown]
# ## Initial Data Exploration

# %%
#using CSV reader to read dataframe into pandas

df = pd.read_csv('zillow_data.csv')

# %%
#initial overview of datasets columns and data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14723 entries, 0 to 14722
# Columns: 272 entries, RegionID to 2018-04
# dtypes: float64(219), int64(49), object(4)
# memory usage: 30.6+ MB

# %%
#exploring the total amount of columns and rows in dataset

df
# Out:
#        RegionID  RegionName                 City State              Metro  \
# 0         84654       60657              Chicago    IL            Chicago
# 1         90668       75070             McKinney    TX  Dallas-Fort Worth
# 2         91982       77494                 Katy    TX            Houston
# 3         84616       60614              Chicago    IL            Chicago
# 4         93144       79936              El Paso    TX            El Paso
# ...         ...         ...                  ...   ...                ...
# 14718     58333        1338             Ashfield    MA    Greenfield Town
# 14719     59107        3293            Woodstock    NH          Claremont
# 14720     75672       40404                Berea    KY           Richmond
# 14721     93733       81225  Mount Crested Butte    CO                NaN
# 14722     95851       89155             Mesquite    NV          Las Vegas
#
#       CountyName  SizeRank   1996-04   1996-05   1996-06  ...  2017-07  \
# 0           Cook         1  334200.0  335400.0  336500.0  ...  1005500
# 1         Collin         2  235700.0  236900.0  236700.0  ...   308000
# 2         Harris         3  210400.0  212200.0  212200.0  ...   321000
# 3           Cook         4  498100.0  500900.0  503100.0  ...  1289800
# 4        El Paso         5   77300.0   77300.0   77300.0  ...   119100
# ...          ...       ...       ...       ...       ...  ...      ...
# 14718   Franklin     14719   94600.0   94300.0   94000.0  ...   216800
# 14719    Grafton     14720   92700.0   92500.0   92400.0  ...   202100
# 14720    Madison     14721   57100.0   57300.0   57500.0  ...   121800
# 14721   Gunnison     14722  191100.0  192400.0  193700.0  ...   662800
# 14722      Clark     14723  176400.0  176300.0  176100.0  ...   333800
#
#        2017-08  2017-09  2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  \
# 0      1007500  1007800  1009600  1013300  1018700  1024400  1030700  1033800
# 1       310000   312500   314100   315000   316600   318100   319600   321100
# 2       320600   320200   320400   320800   321200   321200   323000   326900
# 3      1287700  1287400  1291500  1296600  1299000  1302700  1306400  1308500
# 4       119400   120000   120300   120300   120300   120300   120500   121000
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 14718   217700   218600   218500   218100   216400   213100   209800   209200
# 14719   208400   212200   215200   214300   213100   213700   218300   222700
# 14720   122800   124600   126700   128800   130600   131700   132500   133000
# 14721   671200   682400   695600   695500   694700   706400   705300   681500
# 14722   336400   339700   343800   346800   348900   350400   353000   356000
#
#        2018-04
# 0      1030600
# 1       321800
# 2       329900
# 3      1307000
# 4       121500
# ...        ...
# 14718   209300
# 14719   225800
# 14720   133400
# 14721   664400
# 14722   357200
#
# [14723 rows x 272 columns]

# %%
#observing values and format of the dataframe
df.head()
# Out:
#    RegionID  RegionName      City State              Metro CountyName  \
# 0     84654       60657   Chicago    IL            Chicago       Cook
# 1     90668       75070  McKinney    TX  Dallas-Fort Worth     Collin
# 2     91982       77494      Katy    TX            Houston     Harris
# 3     84616       60614   Chicago    IL            Chicago       Cook
# 4     93144       79936   El Paso    TX            El Paso    El Paso
#
#    SizeRank   1996-04   1996-05   1996-06  ...  2017-07  2017-08  2017-09  \
# 0         1  334200.0  335400.0  336500.0  ...  1005500  1007500  1007800
# 1         2  235700.0  236900.0  236700.0  ...   308000   310000   312500
# 2         3  210400.0  212200.0  212200.0  ...   321000   320600   320200
# 3         4  498100.0  500900.0  503100.0  ...  1289800  1287700  1287400
# 4         5   77300.0   77300.0   77300.0  ...   119100   119400   120000
#
#    2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 0  1009600  1013300  1018700  1024400  1030700  1033800  1030600
# 1   314100   315000   316600   318100   319600   321100   321800
# 2   320400   320800   321200   321200   323000   326900   329900
# 3  1291500  1296600  1299000  1302700  1306400  1308500  1307000
# 4   120300   120300   120300   120300   120500   121000   121500
#
# [5 rows x 272 columns]

# %% [markdown]
# ## Data Understanding

# %% [markdown]
# Within this dataset, 4 of the features are string values, 49 are integers, and 219 are floats. As was mentioned earlier, this dataset is in a wide format instead of a long format. Long format will be necessary for passing the dataset into an ARIMA model. Additional investigation will be necessary to determine if there are any null values in the dataset that could interfere with accurate results.

# %% [markdown]
# ## Check for Null Values

# %%
# checking for null values and returning it as a pandas series
empty=df.isna().sum()
empty.head(20)
# Out:
# RegionID         0
# RegionName       0
# City             0
# State            0
# Metro         1043
# CountyName       0
# SizeRank         0
# 1996-04       1039
# 1996-05       1039
# 1996-06       1039
# 1996-07       1039
# 1996-08       1039
# 1996-09       1039
# 1996-10       1039
# 1996-11       1039
# 1996-12       1039
# 1997-01       1039
# 1997-02       1039
# 1997-03       1039
# 1997-04       1039
# dtype: int64

# %% [markdown]
# After additional investigation, the dataset appears to contain null values in metro and in some of the prices. Since the dataset that will be modeled will be a subset of this dataset, the prescence of null values will be checked again.

# %% [markdown]
# # Data Preparation

# %% [markdown]
# The profit of each zip code will be determined by subtracting the original price of the average property in April of 1996 from the average property value in April of 2018. Due to the client's budget, the available houses will be limited by price, only properties with a value of under $300,000 as of April 2018. Since Compass is a national company, geography is not a limiting factor for investment consideration therefore no geographical constraints will be used to limit the available zipcodes.

# %% [markdown]
# ## Filtering for Properties Under Client Budget

# %% [markdown]
# Since Compass Real Estate is interested in expanding into more middle class housing, the analysis will focus on properties that are under the price of $300,000 as of April 2018.

# %%
#creating new dataframe with only properties that are under $300,000 as of 2018-04
client_budget = df[df['2018-04']<=300000]

# %%
#Examining new dataframe size with budget restrictions
client_budget
# Out:
#        RegionID  RegionName          City State            Metro CountyName  \
# 4         93144       79936       El Paso    TX          El Paso    El Paso
# 5         91733       77084       Houston    TX          Houston     Harris
# 8         91940       77449          Katy    TX          Houston     Harris
# 11        71831       32162  The Villages    FL     The Villages     Sumter
# 14        74101       37013     Nashville    TN        Nashville   Davidson
# ...         ...         ...           ...   ...              ...        ...
# 14715     62556       12429        Esopus    NY         Kingston     Ulster
# 14717     62697       12720        Bethel    NY              NaN   Sullivan
# 14718     58333        1338      Ashfield    MA  Greenfield Town   Franklin
# 14719     59107        3293     Woodstock    NH        Claremont    Grafton
# 14720     75672       40404         Berea    KY         Richmond    Madison
#
#        SizeRank   1996-04   1996-05   1996-06  ...  2017-07  2017-08  2017-09  \
# 4             5   77300.0   77300.0   77300.0  ...   119100   119400   120000
# 5             6   95000.0   95200.0   95400.0  ...   157900   158700   160200
# 8             9   95400.0   95600.0   95800.0  ...   166800   167400   168400
# 11           12  101000.0  100700.0  100400.0  ...   249900   250400   249900
# 14           15  112400.0  112700.0  113000.0  ...   193000   194900   196600
# ...         ...       ...       ...       ...  ...      ...      ...      ...
# 14715     14716   78300.0   78300.0   78200.0  ...   164200   166600   170000
# 14717     14718   62500.0   62600.0   62700.0  ...   122200   122700   122300
# 14718     14719   94600.0   94300.0   94000.0  ...   216800   217700   218600
# 14719     14720   92700.0   92500.0   92400.0  ...   202100   208400   212200
# 14720     14721   57100.0   57300.0   57500.0  ...   121800   122800   124600
#
#        2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 4       120300   120300   120300   120300   120500   121000   121500
# 5       161900   162800   162800   162800   162900   163500   164300
# 8       169600   170900   172300   173300   174200   175400   176200
# 11      248700   247500   247100   246800   247500   249800   251800
# 14      198800   201300   203800   205900   207600   210000   211900
# ...        ...      ...      ...      ...      ...      ...      ...
# 14715   171000   170700   171300   172400   173600   175800   177500
# 14717   122000   122200   122800   123200   123200   120700   117700
# 14718   218500   218100   216400   213100   209800   209200   209300
# 14719   215200   214300   213100   213700   218300   222700   225800
# 14720   126700   128800   130600   131700   132500   133000   133400
#
# [10632 rows x 272 columns]

# %% [markdown]
# Even with the budget limit of $3000,000, Compass Real Estate has many zipcodes to potentially choose from. In order to determine which zipcodes have the greates ROI, a new column will be created to show the total increase in value from April of 1996 to April of 2018.

# %% [markdown]
# ## Creating Total Price Increase Column to Dataframe

# %% [markdown]
# Since the client, Compass Real Estate, is interested in maximizing profits, a new column showing the total increase in price from April of 1996 to April of 2018 will be added to the dataset. As a result, a house that has gained the most value over this time period will be the most desirable for the clients.

# %%
#Creating a new column with April 2018 price minus the price in April of 1996 to show overall value increase over 
#the time period
client_budget.loc[:,'Total Price Increase'] = (
    client_budget['2018-04'] - client_budget['1996-04']
            )

# %%
client_budget
# Out:
#        RegionID  RegionName          City State            Metro CountyName  \
# 4         93144       79936       El Paso    TX          El Paso    El Paso
# 5         91733       77084       Houston    TX          Houston     Harris
# 8         91940       77449          Katy    TX          Houston     Harris
# 11        71831       32162  The Villages    FL     The Villages     Sumter
# 14        74101       37013     Nashville    TN        Nashville   Davidson
# ...         ...         ...           ...   ...              ...        ...
# 14715     62556       12429        Esopus    NY         Kingston     Ulster
# 14717     62697       12720        Bethel    NY              NaN   Sullivan
# 14718     58333        1338      Ashfield    MA  Greenfield Town   Franklin
# 14719     59107        3293     Woodstock    NH        Claremont    Grafton
# 14720     75672       40404         Berea    KY         Richmond    Madison
#
#        SizeRank   1996-04   1996-05   1996-06  ...  2017-08  2017-09  2017-10  \
# 4             5   77300.0   77300.0   77300.0  ...   119400   120000   120300
# 5             6   95000.0   95200.0   95400.0  ...   158700   160200   161900
# 8             9   95400.0   95600.0   95800.0  ...   167400   168400   169600
# 11           12  101000.0  100700.0  100400.0  ...   250400   249900   248700
# 14           15  112400.0  112700.0  113000.0  ...   194900   196600   198800
# ...         ...       ...       ...       ...  ...      ...      ...      ...
# 14715     14716   78300.0   78300.0   78200.0  ...   166600   170000   171000
# 14717     14718   62500.0   62600.0   62700.0  ...   122700   122300   122000
# 14718     14719   94600.0   94300.0   94000.0  ...   217700   218600   218500
# 14719     14720   92700.0   92500.0   92400.0  ...   208400   212200   215200
# 14720     14721   57100.0   57300.0   57500.0  ...   122800   124600   126700
#
#        2017-11  2017-12  2018-01  2018-02  2018-03  2018-04  \
# 4       120300   120300   120300   120500   121000   121500
# 5       162800   162800   162800   162900   163500   164300
# 8       170900   172300   173300   174200   175400   176200
# 11      247500   247100   246800   247500   249800   251800
# 14      201300   203800   205900   207600   210000   211900
# ...        ...      ...      ...      ...      ...      ...
# 14715   170700   171300   172400   173600   175800   177500
# 14717   122200   122800   123200   123200   120700   117700
# 14718   218100   216400   213100   209800   209200   209300
# 14719   214300   213100   213700   218300   222700   225800
# 14720   128800   130600   131700   132500   133000   133400
#
#        Total Price Increase
# 4                   44200.0
# 5                   69300.0
# 8                   80800.0
# 11                 150800.0
# 14                  99500.0
# ...                     ...
# 14715               99200.0
# 14717               55200.0
# 14718              114700.0
# 14719              133100.0
# 14720               76300.0
#
# [10632 rows x 273 columns]

# %% [markdown]
# From the limited view of the available 10,632 rows, a range of profits over time are already evident. It will be necessary to order the data by these values to determine which zip codes have the greatest value increase.

# %% [markdown]
# ## Ordering By Total Price Increase and Creating a Top 25 Zip Code Dataset

# %% [markdown]
# Since the client is limited by resources to only focus on five zipcodes, the top 25 Zip Codes will be modeled to give options for modeling and selecting the top five zip codes that maximize profit.

# %%
#ordering the dataframe from highest value of Total Price Increase to find the top 25 zipcodes 
top_25_zips = client_budget.sort_values(by=['Total Price Increase'], ascending=False).head(25)

# %%
#examine new dataframe of top 25 zipcodes according to total price increase
top_25_zips
# Out:
#        RegionID  RegionName            City State                Metro  \
# 13830     66102       19951        Harbeson    DE            Salisbury
# 14217     93399       80449         Hartsel    CO               Denver
# 3615      65792       19125    Philadelphia    PA         Philadelphia
# 11353     95177       86334         Paulden    AZ             Prescott
# 2656      73011       34120          Naples    FL               Naples
# 8350      92632       78721          Austin    TX               Austin
# 3153      99192       97321          Albany    OR               Albany
# 13470     82893       56511         Audubon    MN                  NaN
# 8743      99229       97370       Philomath    OR            Corvallis
# 10598     64752       16827       Boalsburg    PA        State College
# 1059      64741       16801   State College    PA        State College
# 3878      71886       32233  Atlantic Beach    FL         Jacksonville
# 5727      95167       86323    Chino Valley    AZ             Prescott
# 7636      82259       55409     Minneapolis    MN  Minneapolis-St Paul
# 10414     82858       56442      Cross Lake    MN             Brainerd
# 14685     93405       80456       Jefferson    CO               Denver
# 7121      72928       33947    Rotonda West    FL          Punta Gorda
# 2838      85926       63108     Saint Louis    MO            St. Louis
# 13751     82859       56443         Cushing    MN                  NaN
# 9695      88764       70734         Geismar    LA          Baton Rouge
# 5145      74247       37216       Nashville    TN            Nashville
# 6048      83143       57110     Sioux Falls    SD          Sioux Falls
# 6983      66116       19968          Milton    DE            Salisbury
# 1758      71036       30316         Atlanta    GA              Atlanta
# 4914      72705       33602           Tampa    FL                Tampa
#
#              CountyName  SizeRank  1996-04  1996-05  1996-06  ...  2017-08  \
# 13830            Sussex     13831  34500.0  34900.0  35200.0  ...   258600
# 14217              Park     14218  30000.0  30400.0  30900.0  ...   244600
# 3615       Philadelphia      3616  32600.0  32700.0  32800.0  ...   249000
# 11353           Yavapai     11354  41100.0  41400.0  41700.0  ...   229800
# 2656            Collier      2657  68600.0  67900.0  67200.0  ...   289800
# 8350             Travis      8351  69200.0  68800.0  68400.0  ...   281200
# 3153               Linn      3154  71600.0  71900.0  72200.0  ...   286800
# 13470            Becker     13471  59200.0  59300.0  59500.0  ...   281000
# 8743             Benton      8744  69300.0  69700.0  70000.0  ...   278300
# 10598            Centre     10599  67500.0  67700.0  67900.0  ...   274400
# 1059             Centre      1060  72600.0  72900.0  73000.0  ...   280400
# 3878              Duval      3879  75500.0  75600.0  75700.0  ...   269300
# 5727            Yavapai      5728  68500.0  67500.0  66600.0  ...   264500
# 7636           Hennepin      7637  81500.0  81600.0  81600.0  ...   280100
# 10414         Crow Wing     10415  74300.0  74600.0  74900.0  ...   278300
# 14685              Park     14686  37300.0  38100.0  38800.0  ...   232700
# 7121          Charlotte      7122  39200.0  39100.0  38900.0  ...   245100
# 2838   Saint Louis City      2839  69300.0  69600.0  70100.0  ...   269300
# 13751          Morrison     13752  59500.0  59700.0  59900.0  ...   275200
# 9695          Ascension      9696  56800.0  57000.0  57300.0  ...   268900
# 5145           Davidson      5146  72800.0  72800.0  72800.0  ...   278200
# 6048          Minnehaha      6049  30100.0  31200.0  32300.0  ...   230900
# 6983             Sussex      6984  73400.0  72500.0  71600.0  ...   266400
# 1758             Fulton      1759  62300.0  62300.0  62300.0  ...   244200
# 4914       Hillsborough      4915  57800.0  57700.0  57700.0  ...   252200
#
#        2017-09  2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  2018-04  \
# 13830   258100   260300   265400   269300   272100   275300   277000   276900
# 14217   248000   251300   252900   254700   256600   259200   263400   267700
# 3615    251600   253900   255700   257100   258000   258500   260500   262300
# 11353   232000   237000   242800   249200   253900   257800   263900   269900
# 2656    291800   293800   294000   293700   294600   294700   295100   296200
# 8350    281500   284000   288500   293000   296300   297800   297200   296100
# 3153    288600   289500   289700   290700   292100   293200   295200   297700
# 13470   280500   279100   277700   278100   279800   280100   281400   284300
# 8743    281300   284400   287100   290100   292900   293000   291800   291500
# 10598   277000   278200   279000   279800   279700   280800   284300   287800
# 1059    283300   285400   286800   286900   286600   287400   289900   292200
# 3878    271400   274600   276200   278100   282100   286200   290600   294000
# 5727    265300   266200   268800   272900   276300   279500   283700   286400
# 7636    282800   284800   286200   287800   290000   292100   295300   298200
# 10414   280700   283200   284600   285800   285900   285800   288000   290900
# 14685   235800   238200   240400   243500   246300   248800   251500   253800
# 7121    246900   248100   249800   252300   254700   256500   256700   255700
# 2838    269100   267600   267800   269900   272300   276000   281300   284800
# 13751   275900   275900   272800   268400   265900   266200   270400   274700
# 9695    269700   270100   270300   270700   271500   271600   271200   271100
# 5145    278800   279600   279400   279700   281400   283300   285600   287000
# 6048    232200   233500   234000   234700   236000   237700   240800   243900
# 6983    268100   271700   276600   280200   282500   285100   286800   287100
# 1758    247900   251700   255300   258800   261600   264300   268700   272500
# 4914    253400   254400   257100   259200   260500   262700   265500   267400
#
#        Total Price Increase
# 13830              242400.0
# 14217              237700.0
# 3615               229700.0
# 11353              228800.0
# 2656               227600.0
# 8350               226900.0
# 3153               226100.0
# 13470              225100.0
# 8743               222200.0
# 10598              220300.0
# 1059               219600.0
# 3878               218500.0
# 5727               217900.0
# 7636               216700.0
# 10414              216600.0
# 14685              216500.0
# 7121               216500.0
# 2838               215500.0
# 13751              215200.0
# 9695               214300.0
# 5145               214200.0
# 6048               213800.0
# 6983               213700.0
# 1758               210200.0
# 4914               209600.0
#
# [25 rows x 273 columns]

# %%
empty_25=top_25_zips.isna().sum()
empty_25.head(40)
# Out:
# RegionID      0
# RegionName    0
# City          0
# State         0
# Metro         2
# CountyName    0
# SizeRank      0
# 1996-04       0
# 1996-05       0
# 1996-06       0
# 1996-07       0
# 1996-08       0
# 1996-09       0
# 1996-10       0
# 1996-11       0
# 1996-12       0
# 1997-01       0
# 1997-02       0
# 1997-03       0
# 1997-04       0
# 1997-05       0
# 1997-06       0
# 1997-07       0
# 1997-08       0
# 1997-09       0
# 1997-10       0
# 1997-11       0
# 1997-12       0
# 1998-01       0
# 1998-02       0
# 1998-03       0
# 1998-04       0
# 1998-05       0
# 1998-06       0
# 1998-07       0
# 1998-08       0
# 1998-09       0
# 1998-10       0
# 1998-11       0
# 1998-12       0
# dtype: int64

# %% [markdown]
# After checking, the Top 25 Zip Codes dataset only contains two null values in the Metro column. This feature column is unimportant to the modeling process as this feature will be dropped in favor of using RegionName/Zipcode.

# %% [markdown]
# ## Visualizing the Geographic Spread of the Top 25 Zip Codes

# %% [markdown]
# Despite the client, Compass Real Estate, not being limited to geographic locations, it is valuable to see any geographic trends among the top 25 zipcodes for potential maximizing of resources. A dataset with latitute and longitude values for each Zipcode will be created in order to create a useful visual.

# %%
#extracting the top 25 Zipcodes from the dataset
list(top_25_zips['RegionName'])
# Out:
# [19951,
#  80449,
#  19125,
#  86334,
#  34120,
#  78721,
#  97321,
#  56511,
#  97370,
#  16827,
#  16801,
#  32233,
#  86323,
#  55409,
#  56442,
#  80456,
#  33947,
#  63108,
#  56443,
#  70734,
#  37216,
#  57110,
#  19968,
#  30316,
#  33602]

# %%
#creating a list of values for the longitude and latitude of each Zipcode
coord = [(19951, 38.6898, -75.24000), (80449, 38.95689,-105.87044), (19125, 39.97641,-75.12217), (86334, 34.94867,-112.54443), 
        (34120, 26.32277,-81.55923),(78721, 30.26619,-97.68476), (97321, 44.63339,-123.13956), (56511, 46.84768,-96.01409), (97370, 44.59613,-123.45873), 
         (16827, 40.77297,-77.76024), (16801, 40.78681,-77.84438), (32233, 30.36143,-81.42642), (86323, 34.83896,-112.39677), (55409, 44.92652,-93.29081), (56442, 46.68866,-94.09915),
        (80456, 39.35346,-105.77032), (33947, 26.88093,-82.26993), (63108, 38.64461,-90.25198), (56443, 46.19521,-94.55463), (70734, 30.20703,-91.00902),
        (37216, 36.21681,-86.72443), (57110, 43.54969,-96.63113), (19968, 38.76454,-75.29784), (30316, 33.71759,-84.33225), (33602, 27.94946,-82.46118)]

# %%
#creating a dataframe with the longitude, latitude, and RegionName values
zip_long_lat = pd.DataFrame(coord, columns=['RegionName', 'Latitude', 'Longitude'])

# %%
#examining dataframe
zip_long_lat
# Out:
#     RegionName  Latitude  Longitude
# 0        19951  38.68980  -75.24000
# 1        80449  38.95689 -105.87044
# 2        19125  39.97641  -75.12217
# 3        86334  34.94867 -112.54443
# 4        34120  26.32277  -81.55923
# 5        78721  30.26619  -97.68476
# 6        97321  44.63339 -123.13956
# 7        56511  46.84768  -96.01409
# 8        97370  44.59613 -123.45873
# 9        16827  40.77297  -77.76024
# 10       16801  40.78681  -77.84438
# 11       32233  30.36143  -81.42642
# 12       86323  34.83896 -112.39677
# 13       55409  44.92652  -93.29081
# 14       56442  46.68866  -94.09915
# 15       80456  39.35346 -105.77032
# 16       33947  26.88093  -82.26993
# 17       63108  38.64461  -90.25198
# 18       56443  46.19521  -94.55463
# 19       70734  30.20703  -91.00902
# 20       37216  36.21681  -86.72443
# 21       57110  43.54969  -96.63113
# 22       19968  38.76454  -75.29784
# 23       30316  33.71759  -84.33225
# 24       33602  27.94946  -82.46118

# %%
#merging the latitude and longitude dataframe with the Top 25 Zipcode Dataframe
top_25_full_df = pd.merge(top_25_zips, zip_long_lat, on=["RegionName"])

# %%
#examining new full dataset
top_25_full_df
# Out:
#     RegionID  RegionName            City State                Metro  \
# 0      66102       19951        Harbeson    DE            Salisbury
# 1      93399       80449         Hartsel    CO               Denver
# 2      65792       19125    Philadelphia    PA         Philadelphia
# 3      95177       86334         Paulden    AZ             Prescott
# 4      73011       34120          Naples    FL               Naples
# 5      92632       78721          Austin    TX               Austin
# 6      99192       97321          Albany    OR               Albany
# 7      82893       56511         Audubon    MN                  NaN
# 8      99229       97370       Philomath    OR            Corvallis
# 9      64752       16827       Boalsburg    PA        State College
# 10     64741       16801   State College    PA        State College
# 11     71886       32233  Atlantic Beach    FL         Jacksonville
# 12     95167       86323    Chino Valley    AZ             Prescott
# 13     82259       55409     Minneapolis    MN  Minneapolis-St Paul
# 14     82858       56442      Cross Lake    MN             Brainerd
# 15     93405       80456       Jefferson    CO               Denver
# 16     72928       33947    Rotonda West    FL          Punta Gorda
# 17     85926       63108     Saint Louis    MO            St. Louis
# 18     82859       56443         Cushing    MN                  NaN
# 19     88764       70734         Geismar    LA          Baton Rouge
# 20     74247       37216       Nashville    TN            Nashville
# 21     83143       57110     Sioux Falls    SD          Sioux Falls
# 22     66116       19968          Milton    DE            Salisbury
# 23     71036       30316         Atlanta    GA              Atlanta
# 24     72705       33602           Tampa    FL                Tampa
#
#           CountyName  SizeRank  1996-04  1996-05  1996-06  ...  2017-10  \
# 0             Sussex     13831  34500.0  34900.0  35200.0  ...   260300
# 1               Park     14218  30000.0  30400.0  30900.0  ...   251300
# 2       Philadelphia      3616  32600.0  32700.0  32800.0  ...   253900
# 3            Yavapai     11354  41100.0  41400.0  41700.0  ...   237000
# 4            Collier      2657  68600.0  67900.0  67200.0  ...   293800
# 5             Travis      8351  69200.0  68800.0  68400.0  ...   284000
# 6               Linn      3154  71600.0  71900.0  72200.0  ...   289500
# 7             Becker     13471  59200.0  59300.0  59500.0  ...   279100
# 8             Benton      8744  69300.0  69700.0  70000.0  ...   284400
# 9             Centre     10599  67500.0  67700.0  67900.0  ...   278200
# 10            Centre      1060  72600.0  72900.0  73000.0  ...   285400
# 11             Duval      3879  75500.0  75600.0  75700.0  ...   274600
# 12           Yavapai      5728  68500.0  67500.0  66600.0  ...   266200
# 13          Hennepin      7637  81500.0  81600.0  81600.0  ...   284800
# 14         Crow Wing     10415  74300.0  74600.0  74900.0  ...   283200
# 15              Park     14686  37300.0  38100.0  38800.0  ...   238200
# 16         Charlotte      7122  39200.0  39100.0  38900.0  ...   248100
# 17  Saint Louis City      2839  69300.0  69600.0  70100.0  ...   267600
# 18          Morrison     13752  59500.0  59700.0  59900.0  ...   275900
# 19         Ascension      9696  56800.0  57000.0  57300.0  ...   270100
# 20          Davidson      5146  72800.0  72800.0  72800.0  ...   279600
# 21         Minnehaha      6049  30100.0  31200.0  32300.0  ...   233500
# 22            Sussex      6984  73400.0  72500.0  71600.0  ...   271700
# 23            Fulton      1759  62300.0  62300.0  62300.0  ...   251700
# 24      Hillsborough      4915  57800.0  57700.0  57700.0  ...   254400
#
#     2017-11  2017-12  2018-01  2018-02  2018-03  2018-04  \
# 0    265400   269300   272100   275300   277000   276900
# 1    252900   254700   256600   259200   263400   267700
# 2    255700   257100   258000   258500   260500   262300
# 3    242800   249200   253900   257800   263900   269900
# 4    294000   293700   294600   294700   295100   296200
# 5    288500   293000   296300   297800   297200   296100
# 6    289700   290700   292100   293200   295200   297700
# 7    277700   278100   279800   280100   281400   284300
# 8    287100   290100   292900   293000   291800   291500
# 9    279000   279800   279700   280800   284300   287800
# 10   286800   286900   286600   287400   289900   292200
# 11   276200   278100   282100   286200   290600   294000
# 12   268800   272900   276300   279500   283700   286400
# 13   286200   287800   290000   292100   295300   298200
# 14   284600   285800   285900   285800   288000   290900
# 15   240400   243500   246300   248800   251500   253800
# 16   249800   252300   254700   256500   256700   255700
# 17   267800   269900   272300   276000   281300   284800
# 18   272800   268400   265900   266200   270400   274700
# 19   270300   270700   271500   271600   271200   271100
# 20   279400   279700   281400   283300   285600   287000
# 21   234000   234700   236000   237700   240800   243900
# 22   276600   280200   282500   285100   286800   287100
# 23   255300   258800   261600   264300   268700   272500
# 24   257100   259200   260500   262700   265500   267400
#
#     Total Price Increase  Latitude  Longitude
# 0               242400.0  38.68980  -75.24000
# 1               237700.0  38.95689 -105.87044
# 2               229700.0  39.97641  -75.12217
# 3               228800.0  34.94867 -112.54443
# 4               227600.0  26.32277  -81.55923
# 5               226900.0  30.26619  -97.68476
# 6               226100.0  44.63339 -123.13956
# 7               225100.0  46.84768  -96.01409
# 8               222200.0  44.59613 -123.45873
# 9               220300.0  40.77297  -77.76024
# 10              219600.0  40.78681  -77.84438
# 11              218500.0  30.36143  -81.42642
# 12              217900.0  34.83896 -112.39677
# 13              216700.0  44.92652  -93.29081
# 14              216600.0  46.68866  -94.09915
# 15              216500.0  39.35346 -105.77032
# 16              216500.0  26.88093  -82.26993
# 17              215500.0  38.64461  -90.25198
# 18              215200.0  46.19521  -94.55463
# 19              214300.0  30.20703  -91.00902
# 20              214200.0  36.21681  -86.72443
# 21              213800.0  43.54969  -96.63113
# 22              213700.0  38.76454  -75.29784
# 23              210200.0  33.71759  -84.33225
# 24              209600.0  27.94946  -82.46118
#
# [25 rows x 275 columns]

# %%
#Importinga shp of the USA map for visualization
mapdf = top_25_full_df.copy()

usa_map = gpd.read_file('tl_2017_us_state/tl_2017_us_state.shp')
usa_map = usa_map.to_crs("EPSG:4326")

# %%
#examining SHP file
usa_map.plot();

# %%
#Removing Non Continental States from Visualization
non_continental = ['HI','VI','MP','GU','AK','AS','PR']
us49 = usa_map
for n in non_continental:
    us49 = us49[us49.STUSPS != n]

# %%
#examining new chart
us49.boundary.plot()
plt.show()

# %%
#Plotting the Top 25 Zip Codes on USA Chart
crs = {'init':'EPSG:4326'} #define CRS
geometry = [Point(xy) for xy in zip(mapdf['Longitude'], top_25_full_df['Latitude'])] #create Points
geo_df = gpd.GeoDataFrame(mapdf, 
                          crs = crs, 
                          geometry = geometry) #define the geometry df

#plot the data
fig, ax = plt.subplots(figsize = (10,10))
us49.to_crs(epsg=4326).plot(ax=ax)
sns.scatterplot(x="Longitude", y="Latitude",data=mapdf, ax=ax)
ax.set_title('Distribution of Top 25 Most Profitable Zip Codes');

# %% [markdown]
# As can be seen on the chart, there are some interesting geographic concentrations that could be of interest to the clients if there was a desire to consolidate resources geographically. The analysis of this project, however, will move forward with recommendations based solely on ROI considerations with no geographic consideration.

# %% [markdown]
# ## Visualizing the Price history of filtered Zip Codes since 1996

# %% [markdown]
# An important aspect of times series data anlysis is making sure that the modeling is not overall affected by seasonality or trends within the data. To get a better sense of the shape of the price history, a visualization of the price history since 1996 will be utilized.

# %%
#creating a function to convert the dataset from wide format to long format
def melt_data(df):
    """
    Takes the zillow_data dataset in wide form or a subset of the zillow_dataset.  
    Returns a long-form datetime dataframe 
    with the datetime column names as the index and the values as the 'values' column.
    
    If more than one row is passes in the wide-form dataset, the values column
    will be the mean of the values from the datetime columns in all of the rows.
    """
    
    melted = pd.melt(df, id_vars=['RegionName', 'RegionID', 'SizeRank', 'City', 'State', 'Metro', 'CountyName'], var_name='time')
    melted['time'] = pd.to_datetime(melted['time'], infer_datetime_format=True)
    melted = melted.dropna(subset=['value'])
    return melted.groupby('time').aggregate({'value':'mean'})

# %%
#drop extra columns not needed for modeling
top_25_modeling_df = top_25_full_df.drop(['Total Price Increase', 'Latitude', 'Longitude'], axis=1)

# %%
#examine new dataset with dropped columns for modeling
top_25_modeling_df.head()
# Out:
#    RegionID  RegionName          City State         Metro    CountyName  \
# 0     66102       19951      Harbeson    DE     Salisbury        Sussex
# 1     93399       80449       Hartsel    CO        Denver          Park
# 2     65792       19125  Philadelphia    PA  Philadelphia  Philadelphia
# 3     95177       86334       Paulden    AZ      Prescott       Yavapai
# 4     73011       34120        Naples    FL        Naples       Collier
#
#    SizeRank  1996-04  1996-05  1996-06  ...  2017-07  2017-08  2017-09  \
# 0     13831  34500.0  34900.0  35200.0  ...   260000   258600   258100
# 1     14218  30000.0  30400.0  30900.0  ...   243200   244600   248000
# 2      3616  32600.0  32700.0  32800.0  ...   247500   249000   251600
# 3     11354  41100.0  41400.0  41700.0  ...   230300   229800   232000
# 4      2657  68600.0  67900.0  67200.0  ...   288300   289800   291800
#
#    2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 0   260300   265400   269300   272100   275300   277000   276900
# 1   251300   252900   254700   256600   259200   263400   267700
# 2   253900   255700   257100   258000   258500   260500   262300
# 3   237000   242800   249200   253900   257800   263900   269900
# 4   293800   294000   293700   294600   294700   295100   296200
#
# [5 rows x 272 columns]

# %%
#creating plot of prices changes by zipcode since 1996
zip_dict = {}

for zipcode in top_25_modeling_df['RegionName']:
    zip_dict[zipcode] = melt_data(top_25_modeling_df[top_25_modeling_df['RegionName']==zipcode])

fig,ax = plt.subplots(figsize=(20,12))

for zipcode in zip_dict:
    ax.plot(zip_dict[zipcode],)

ax.axhline(y=300000,label = 'Client Budget')   

ax.set_title('ZipCode Price Changes since 1996',fontsize=30)
ax.set_ylabel('Price in US $',fontsize=20)
ax.set_xlabel('Year',fontsize=20)
ax.legend(prop={'size': 25});

# %% [markdown]
# As can be seen in the visualization, there was an increase of prices and then a steep decline around 2008. This corresponds with the 2008 financial housing crisis and recession. Since then, it appears that prices have been steadily on the rise since 2011 but have yet to reach their pre-recession peaks. There area also some interesting outliers in the data that grew and declined rapidly around 2008.

# %% [markdown]
# ## Visualizing the The Zip Codes' Average Price Growth since 2011

# %% [markdown]
# Since the event of the 2008 financial recession had an outsized affect on the housing prices in the dataset, focusing on the prices after the impacts of this event seem to be the most effective data for modeling and prediction. Creating a visualization of which zipcodes have been growing the fastest since then will be a helpful tool to determine which zipcodes should be used for modeling.

# %%
#creating a bar graph visual that shows the average return on investment for each of the top 25 zipcodes
warnings.filterwarnings('ignore')

#creating column with ROI since 2011
top_25_2011_roi = top_25_modeling_df
top_25_2011_roi['roi_since11'] = (
    (top_25_2011_roi['2018-04']-top_25_2011_roi['2011-01'])/(top_25_2011_roi['2011-01'])*100)
top_25_2011_roi = top_25_2011_roi.sort_values('roi_since11',ascending=False)

warnings.filterwarnings('ignore')

#plotting column roi_since11 for each zipcode
fig,ax=plt.subplots(figsize=(18,12))

x_labels = [str(a) for a in top_25_2011_roi['RegionName']]
x = list(range(1,26))
y = [a for a in top_25_2011_roi['roi_since11']]

ax.bar(x,y)

ax.set_xticks(x)
ax.set_xticklabels(x_labels)
ax.set_ylabel('% Growth',fontsize='20')
ax.set_xlabel('Zipcodes',fontsize='20')
ax.set_title('Avg % Return on Investment',fontsize='30');

# %% [markdown]
# We can see from above that the highest growing zip code since 2011 is 33602. It is also of interest to note that the top three zipcodes seem concentrated around the same geographic area. Areas of growth not being limited to one zipcode is an interesting oppurtunity for clients to acheive the highest ROI while also concentrating resources.

# %% [markdown]
# # Selecting a ZipCode for the Initial Time Series Model

# %% [markdown]
# In order to build a time series model that predicts the future ROI of each of the top 25 zipcodes within the client's budget, an initial time series model must be built on one of the zipcodes in the dataset. Since zipcode 33602 is the fastest growing it will be used to construct the initial time series model. Therefore, the first time series model will predict what the future value of 33602 will be. A similar workflow can then be utilized on the other zipcodes within the dataset to identify which five zipcodes have the highest predicted ROI.

# %%
#dataframe containing zipcode 33602
zip33602 = df[df['RegionName']==33602]

# %%
#melting zipcode 33602 from wide to long format
series33602 = melt_data(zip33602)

# %%
#examining 33602 long format dataset
series33602
# Out:
#                value
# time
# 1996-04-01   57800.0
# 1996-05-01   57700.0
# 1996-06-01   57700.0
# 1996-07-01   57600.0
# 1996-08-01   57500.0
# ...              ...
# 2017-12-01  259200.0
# 2018-01-01  260500.0
# 2018-02-01  262700.0
# 2018-03-01  265500.0
# 2018-04-01  267400.0
#
# [265 rows x 1 columns]

# %%
#Visualizing the Time Series Data for zipcode- 33602

fig, ax = plt.subplots(figsize=(20,12))
ax.plot(series33602)

ax.set_xlabel('Year', fontsize=30)
ax.set_ylabel('Price in 100,000($)',fontsize=20)
ax.set_title('Zip Code 33602 Price History',fontsize=30);

# %% [markdown]
# After having examined the price history of all the zipcodes in the top 25 dataset, individually the zipcode of 33602 follows similar patterns. There is a sharp increase in price followed by a deep descent around the year 2008, and then after a steadier increase starting in 2011. As a result, it seems reasonable to expect that a time series model of this individual zipcode will also be successful with the remaining zipcodes in the dataset.

# %% [markdown]
# ## Relevance of Recent Data

# %% [markdown]
# Since the events of the 2008 financial crisis had an outsized impact on the housing prices before 2011, the time series model will be built only using information from 2011 and on. This will help the time series model be an accurate reflection of the current state of today's markets.

# %%
#dataset of only 2011 dates and on
recent_series = series33602['2011':]

# %%
#Visualizing the Time Series Data for zipcode- 33602 from 2011

fig, ax = plt.subplots(figsize=(20,12))
ax.plot(recent_series)

ax.set_xlabel('Year', fontsize=20)
ax.set_ylabel('Price in 100,000($)',fontsize=20)
ax.set_title('Zip Code 33602- Price since 2011',fontsize=30);

# %% [markdown]
# By eliminating the average prices before 2011, the graph shows only a positive trend of a mostly linear growth in average price. This trend is the data that the model will be built and tested on.

# %% [markdown]
# # Model Training and Testing

# %% [markdown]
# For time series modeling a stationary dataset is usually required to create an accurate prediction model. However, by utilizing an AUTO-ARIMA model, the model itself will generate the optimal values to eliminate stationarity and create predictions. As a result, in order to streamline the process of modeling a AUTO-ARIMA model will be built using the data from the 33602 zipcode.

# %%
#testing data with Dickey-Fuller Test
from pmdarima.arima import ADFTest
adf_test = ADFTest(alpha = 0.05)
adf_test.should_diff(recent_series)
# Out:
# (0.5513778725771431, True)

# %% [markdown]
# After using the agumented Dickey-Fuller Test, it can be concluded that the data is stationary. This could be the result of limiting the dataset to only data after 2011 and therefore eliminating many of the seasonal trends and patterns.

# %% [markdown]
# ## Splitting Our Data into Train and Test

# %% [markdown]
# In order to evaluate the accuracy of the predictions generated by the AUTO-ARIMA model, a train test split will be utilized.

# %%
# Splitting the last 24 months of our series as a test dataset.
train_series = recent_series[:'2016-04']
test_series = recent_series['2016-05':]

# %% [markdown]
# # Fitting an AUTO-ARIMA Model on our Training Series

# %%
# Creating and Fitting an AUTO ARIMA model to the train dataset
import pmdarima as pm

auto_model = pm.auto_arima(train_series, start_p=0, start_q=0,
                     test='adf',
                     max_p=5, max_q=5,
                     m=1,
                     d=0,
                     seasonal = True,
                     start_P=0,start_Q=0,
                     D=0,
                     trace=True,
                     error_action= 'ignore',
                     suppress_warnings=True,
                     stepwise=True,with_intercept=False)



print(auto_model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1698.308, Time=0.03 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1656.859, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=1107.143, Time=0.05 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=inf, Time=0.08 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=1067.719, Time=0.07 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1650.469, Time=0.01 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.08 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=inf, Time=0.07 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=1651.671, Time=0.02 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=inf, Time=0.08 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.07 sec
#
# Best model:  ARIMA(1,0,2)(0,0,0)[0]
# Total fit time: 0.623 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   64
# Model:               SARIMAX(1, 0, 2)   Log Likelihood                -529.860
# Date:                Fri, 19 May 2023   AIC                           1067.719
# Time:                        07:20:14   BIC                           1076.355
# Sample:                    01-01-2011   HQIC                          1071.121
#                          - 04-01-2016
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9999      0.000   2019.788      0.000       0.999       1.001
# ma.L1          1.6105      0.165      9.766      0.000       1.287       1.934
# ma.L2          0.9770      0.212      4.609      0.000       0.561       1.392
# sigma2      7.069e+05   2.63e-07   2.69e+12      0.000    7.07e+05    7.07e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   2.38   Jarque-Bera (JB):                 2.35
# Prob(Q):                              0.12   Prob(JB):                         0.31
# Heteroskedasticity (H):               1.76   Skew:                             0.07
# Prob(H) (two-sided):                  0.21   Kurtosis:                         2.07
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 3.64e+27. Standard errors may be unstable.

# %%
#Identifying the order values for the model
auto_model.order
# Out:
# (1, 0, 2)

# %%
#Identifying the Seasonal Order values for the model
auto_model.seasonal_order
# Out:
# (0, 0, 0, 0)

# %%
# Plug the optimal parameter values into a new SARIMAX model
ARIMA_MODEL = sm.tsa.statespace.SARIMAX(train_series, 
                                        order=(1,0,2), 
                                        seasonal_order=(0, 0, 0, 0), 
                                        enforce_stationarity=False, 
                                        enforce_invertibility=False)

# Fit the model and print results
output = ARIMA_MODEL.fit()

print(output.summary().tables[1])
auto_model.plot_diagnostics(figsize=(18,18))
plt.show()
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.83499D+00    |proj g|=  2.02487D+00
#
# At iterate    5    f=  7.77345D+00    |proj g|=  1.99391D-01
#
# At iterate   10    f=  7.70126D+00    |proj g|=  1.70371D-01
#
# At iterate   15    f=  7.68922D+00    |proj g|=  9.78582D-03
#
# At iterate   20    f=  7.68821D+00    |proj g|=  1.89053D-01
#
# At iterate   25    f=  7.66956D+00    |proj g|=  3.90490D-01
#
# At iterate   30    f=  7.66869D+00    |proj g|=  1.11459D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     31     45      1     0     0   3.270D-04   7.669D+00
#   F =   7.6686866141091574
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.0106      0.002    433.125      0.000       1.006       1.015
# ma.L1          1.3870      0.125     11.122      0.000       1.143       1.631
# ma.L2          0.8074      0.122      6.591      0.000       0.567       1.047
# sigma2      5.514e+05   2.27e-08   2.43e+13      0.000    5.51e+05    5.51e+05
# ==============================================================================
#  This problem is unconstrained.

# %% [markdown]
# It is important to confirm that the residuals are not correlated and that they are normally distributed. Otherwise, additional changes will need to be made to the model.
#
# Checking each of the diagnostic plots:
#
# - In the plot on the top right, the KDE line somewhat closely follows along the N(0,1) line which is the standard notation for a normal distribution having a mean of 0 and a standard deviation of 1. As a result, this can be interpreted to mean that the residuals are normally distributed.
#
# - The qq-plot shwon on the bottom left displays that the residuals follow the linear trend line. As a result, it can also be interpreted to mean that the residuals are normally distributed.
#
# - From the Correlogram plot on the bottom left, it can be seen that the time series residuals displace low correlation with their lagged versions. This becomes clearer as the time series continues further along. This seems to indicate that there isn't any obvious seasonality in our series.
#
# Based on these observations, it can be confidently concluded that the model does not have correlations and that it satisfactorily fits the data to forecast future prices.

# %% [markdown]
# # Testing our model performance

# %% [markdown]
# In order to test the accuracy of the model, the predictions for the period between May 2016 and April 2018 will be retrieved. The predictions will be plotted on the same chart to see how far and/or close they are.

# %%
# Get predictions starting from 04-01-2015 and calculate confidence intervals
pred = output.get_prediction(start=pd.to_datetime('2016-05'), end=pd.to_datetime('2018-04'), dynamic=False)
pred_conf = pred.conf_int()
pred_conf
# Out:
#               lower value    upper value
# 2016-05-01  191850.779739  194761.445788
# 2016-06-01  192485.848307  200047.158610
# 2016-07-01  192311.895981  204377.552401
# 2016-08-01  192765.939333  208123.962116
# 2016-09-01  193510.928333  211623.903811
# 2016-10-01  194437.945285  214986.766145
# 2016-11-01  195495.444257  218264.571002
# 2016-12-01  196654.293944  221486.930675
# 2017-01-01  197896.192465  224672.633131
# 2017-02-01  199208.798276  227834.511141
# 2017-03-01  200583.356812  230981.815705
# 2017-04-01  202013.418223  234121.498357
# 2017-05-01  203494.089771  237258.958840
# 2017-06-01  205021.573493  240398.507482
# 2017-07-01  206592.866536  243543.664933
# 2017-08-01  208205.559302  246697.364068
# 2017-09-01  209857.695059  249862.090435
# 2017-10-01  211547.669608  253039.982653
# 2017-11-01  213274.157890  256232.905856
# 2017-12-01  215036.059201  259442.506544
# 2018-01-01  216832.455566  262670.254265
# 2018-02-01  218662.579614  265917.473807
# 2018-03-01  220525.789435  269185.370394
# 2018-04-01  222421.548659  272475.049682

# %%
# Plot real vs predicted values along with confidence interval

rcParams['figure.figsize'] = 18, 8

# Plot observed values
ax = recent_series.plot(label='observed')

# Plot predicted values
pred.predicted_mean.plot(ax=ax, label='Prediction Series', alpha=0.9)

# Plot the range for confidence intervals
ax.fill_between(pred_conf.index,
                pred_conf.iloc[:, 0],
                pred_conf.iloc[:, 1], color='lightpink', alpha=0.5,label = 'Confidence Interval')

# Set axes labels
ax.set_xlabel('Date',fontsize=20)
ax.set_ylabel('Price',fontsize=20)
ax.set_title('Testing Forecasting Model Performance',fontsize=30)
plt.legend()

plt.show()

# %% [markdown]
# # Forecasting the Future

# %%
# Plug the parameter values from our Auto ARIMA model into a new SARIMAX model that fits the entire series.
ARIMA_MODEL = sm.tsa.statespace.SARIMAX(recent_series, 
                                        order=(1,0,2), 
                                        seasonal_order=(0, 0, 0, 0), 
                                        enforce_stationarity=False, 
                                        enforce_invertibility=False)

# Fit the model and print results
full_output = ARIMA_MODEL.fit()

print(output.summary().tables[1])
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.88969D+00    |proj g|=  1.33452D+00
#
# At iterate    5    f=  7.87129D+00    |proj g|=  1.51746D-01
#
# At iterate   10    f=  7.86277D+00    |proj g|=  1.30572D+00
#
# At iterate   15    f=  7.80844D+00    |proj g|=  5.04728D-02
#
# At iterate   20    f=  7.80583D+00    |proj g|=  7.17502D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     22     31      1     0     0   5.906D-04   7.806D+00
#   F =   7.8058249292844417
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.0106      0.002    433.125      0.000       1.006       1.015
# ma.L1          1.3870      0.125     11.122      0.000       1.143       1.631
# ma.L2          0.8074      0.122      6.591      0.000       0.567       1.047
# sigma2      5.514e+05   2.27e-08   2.43e+13      0.000    5.51e+05    5.51e+05
# ==============================================================================
#  This problem is unconstrained.

# %%
## Getting a forecast for the next 36 months after the last recorded date on our dataset.
forecast = full_output.get_forecast(36)
future_prediction = forecast.conf_int()
future_prediction['value'] = forecast.predicted_mean
future_prediction.columns = ['lower','upper','prediction'] 
future_prediction
# Out:
#                     lower          upper     prediction
# 2018-05-01  267449.090478  271152.122173  269300.606326
# 2018-06-01  266807.310624  276933.474771  271870.392698
# 2018-07-01  266819.736017  283194.528537  275007.132277
# 2018-08-01  267720.955811  288639.168973  278180.062392
# 2018-09-01  269030.981844  293748.219347  281389.600596
# 2018-10-01  270597.511401  298674.827117  284636.169259
# 2018-11-01  272349.016253  303491.374997  287920.195625
# 2018-12-01  274245.274440  308238.949294  291242.111867
# 2019-01-01  276261.119564  312943.590726  294602.355145
# 2019-02-01  278379.646115  317623.089206  298001.367661
# 2019-03-01  280588.909124  322290.284316  301439.596720
# 2019-04-01  282880.145666  326954.843912  304917.494789
# 2019-05-01  285246.740008  331624.299100  308435.519554
# 2019-06-01  287683.584680  336304.683282  311994.133981
# 2019-07-01  290186.666895  341000.945864  315593.806380
# 2019-08-01  292752.790290  345717.230631  319235.010461
# 2019-09-01  295379.381591  350457.069213  322918.225402
# 2019-10-01  298064.352564  355223.519253  326643.935908
# 2019-11-01  300805.999117  360019.265440  330412.632278
# 2019-12-01  303602.926039  364846.694894  334224.810467
# 2020-01-01  306453.989859  369707.954443  338080.972151
# 2020-02-01  309358.254771  374604.994820  341981.624796
# 2020-03-01  312314.958173  379539.605270  345927.281721
# 2020-04-01  315323.483362  384513.440980  349918.462171
# 2020-05-01  318383.337682  389528.045073  353955.691377
# 2020-06-01  321494.134835  394584.866434  358039.500634
# 2020-07-01  324655.580440  399685.274291  362170.427365
# 2020-08-01  327867.460145  404830.570243  366349.015194
# 2020-09-01  331129.629761  410021.998273  370575.814017
# 2020-10-01  334442.007014  415260.753134  374851.380074
# 2020-11-01  337804.564618  420547.987429  379176.276023
# 2020-12-01  341217.324405  425884.817626  383551.071016
# 2021-01-01  344680.352338  431272.329197  387976.340767
# 2021-02-01  348193.754239  436711.581035  392452.667637
# 2021-03-01  351757.672131  442203.609274  396980.640703
# 2021-04-01  355372.281073  447749.430606  401560.855839

# %%
#Plotting our Forecast

fig, ax = plt.subplots()
recent_series.plot(ax=ax,label='Real Values')


future_prediction['prediction'].plot(ax=ax,label='predicted value',ls='--')

ax.fill_between(x= future_prediction.index, y1= future_prediction['lower'], 
                y2= future_prediction['upper'],color='lightpink',
                label='Confidence Interval')
ax.legend() 
plt.ylabel("Average Price")
plt.title('Average Home Price - 33602 - With Forcasted Value & Confidence Intervals')
plt.show()

# %% [markdown]
# # Forecasting on All Top 25 Zip Codes in Clients Budget

# %%
zip_predictions = {}
top_25_for_modeling = top_25_modeling_df.drop(columns='roi_since11')

for zipcode in top_25_for_modeling['RegionName']:

    series = melt_data(top_25_for_modeling[top_25_for_modeling['RegionName']==zipcode])
   
    #Only taking data from 2011 onwards to more accurately reflect current market conditions
    recent_series = series['2011':]
    
    #Splitting the last 36 months of our series as a test dataset.
    train_series = recent_series[:'2016-04']
    test_series = recent_series['2016-05':]
    
    #Auto ARIMA model
    auto_model = pm.auto_arima(train_series, start_p=0, start_q=0,
                     test='adf',
                     max_p=5, max_q=5,
                     m=1,
                     d=0,
                     seasonal = True,
                     start_P=0,start_Q=0,
                     D=0,
                     trace=True,
                     error_action= 'ignore',
                     suppress_warnings=True,
                     stepwise=True,with_intercept=False)
   
    # Plug the optimal parameter values for our Training data into a SARIMAX model that fits our entire series.
    ARIMA_MODEL = sm.tsa.statespace.SARIMAX(recent_series, 
                                            order= auto_model.order, 
                                            seasonal_order= auto_model.seasonal_order, 
                                            enforce_stationarity=False, 
                                            enforce_invertibility=False)

    # Fit the model and print results
    output = ARIMA_MODEL.fit()

    ## Getting a forecast for the next 36 months after the last absrecorded date on our dataset.
    forecast = output.get_forecast(36)
    prediction = forecast.conf_int()
    prediction['value'] = forecast.predicted_mean
    prediction.columns = ['lower','upper','prediction'] 
    
    #Adding the Zipcode's ROI to the zip_predictions dictionary
    zip_predictions[zipcode] = ((prediction['prediction'][-1])
                                - (series['value'][-1]))/ (series['value'][-1])
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1773.019, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1730.756, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=1148.736, Time=0.03 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=inf, Time=0.06 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=1114.890, Time=0.08 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1722.744, Time=0.02 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.08 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=1122.120, Time=0.08 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=1722.365, Time=0.02 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=inf, Time=0.09 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=1111.571, Time=0.04 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.05 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.07 sec
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=1112.693, Time=0.04 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=1112.144, Time=0.10 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.02 sec
#  ARIMA(0,0,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.07 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=1120.058, Time=0.02 sec
#  ARIMA(2,0,3)(0,0,0)[0] intercept   : AIC=1113.851, Time=0.08 sec
#
# Best model:  ARIMA(1,0,2)(0,0,0)[0] intercept
# Total fit time: 0.991 seconds
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.25491D+00    |proj g|=  4.06594D-01
#
# At iterate    5    f=  8.23244D+00    |proj g|=  9.63333D-02
#
# At iterate   10    f=  8.21993D+00    |proj g|=  1.93206D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     12     19      1     0     0   6.789D-04   8.220D+00
#   F =   8.2199257954734701
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1733.469, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1691.558, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=1063.898, Time=0.04 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=inf, Time=0.07 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=1032.505, Time=0.06 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1684.295, Time=0.01 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.08 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=inf, Time=0.05 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=1683.610, Time=0.02 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=inf, Time=0.09 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.10 sec
#
# Best model:  ARIMA(1,0,2)(0,0,0)[0]
# Total fit time: 0.563 seconds
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.61484D+00    |proj g|=  3.11695D-01
#
# At iterate    5    f=  7.61424D+00    |proj g|=  1.68922D+00
#
# At iterate   10    f=  7.61394D+00    |proj g|=  3.43073D-01
#
# At iterate   15    f=  7.61273D+00    |proj g|=  2.49198D+00
#
# At iterate   20    f=  7.61180D+00    |proj g|=  1.52206D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     20     41      1     0     0   1.522D-03   7.612D+00
#   F =   7.6118025886457126
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1708.356, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1666.495, Time=0.01 sec
#  This problem is unconstrained.
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=1100.059, Time=0.04 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=inf, Time=0.05 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=inf, Time=0.07 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1659.707, Time=0.01 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=inf, Time=0.04 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.12 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=1256.294, Time=0.09 sec
#
# Best model:  ARIMA(1,0,1)(0,0,0)[0]
# Total fit time: 0.472 seconds
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.22326D+00    |proj g|=  5.16723D-01
#
# At iterate    5    f=  8.13269D+00    |proj g|=  1.59382D-01
#
# At iterate   10    f=  8.13229D+00    |proj g|=  2.74499D-01
#
# At iterate   15    f=  8.12245D+00    |proj g|=  1.45506D+00
#
# At iterate   20    f=  8.08640D+00    |proj g|=  5.08560D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     23     75      2     0     0   1.623D-02   8.086D+00
#   F =   8.0862473621483932
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1718.168, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.02 sec
#  This problem is unconstrained.
#
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1676.538, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=1141.565, Time=0.05 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=1107.854, Time=0.08 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=inf, Time=0.04 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=inf, Time=0.08 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.09 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=inf, Time=0.08 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=inf, Time=0.08 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=inf, Time=0.09 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=1109.590, Time=0.09 sec
#
# Best model:  ARIMA(2,0,1)(0,0,0)[0]
# Total fit time: 0.718 seconds
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.03185D+01    |proj g|=  1.39096D+01
#
# At iterate    5    f=  8.66389D+00    |proj g|=  2.16198D+00
#
# At iterate   10    f=  8.65829D+00    |proj g|=  3.36514D+00
#  This problem is unconstrained.
# At iterate   15    f=  8.58987D+00    |proj g|=  2.94527D+01
#
# At iterate   20    f=  8.55679D+00    |proj g|=  1.54776D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     21     28      1     0     0   7.808D-05   8.557D+00
#   F =   8.5567902173713435
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1744.921, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.08 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1703.645, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=1117.447, Time=0.06 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=1022.405, Time=0.09 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=inf, Time=0.04 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=inf, Time=0.06 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.09 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=inf, Time=0.06 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=inf, Time=0.03 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=1024.063, Time=0.10 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.09 sec
#
# Best model:  ARIMA(2,0,1)(0,0,0)[0]
# Total fit time: 0.742 seconds
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.99617D+00    |proj g|=  3.49696D+01
#
# At iterate    5    f=  9.39598D+00    |proj g|=  1.82961D+02
#
# At iterate   10    f=  7.90988D+00    |proj g|=  7.85873D-01
#
# At iterate   15    f=  7.90971D+00    |proj g|=  2.09605D+00
#
# At iterate   20    f=  7.89001D+00    |proj g|=  2.27575D+01
#
# At iterate   25    f=  7.84874D+00    |proj g|=  1.79996D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     28     47      1     0     0   4.894D-03   7.849D+00
#   F =   7.8487373491892214
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1725.341, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1683.576, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=inf, Time=0.03 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1676.901, Time=0.02 sec
#  This problem is unconstrained.
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=1054.742, Time=0.07 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.09 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=1039.177, Time=0.08 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=1677.315, Time=0.02 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=inf, Time=0.09 sec
#  ARIMA(1,0,4)(0,0,0)[0]             : AIC=1044.393, Time=0.10 sec
#  ARIMA(0,0,4)(0,0,0)[0]             : AIC=1678.912, Time=0.02 sec
#  ARIMA(2,0,4)(0,0,0)[0]             : AIC=inf, Time=0.11 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.08 sec
#
# Best model:  ARIMA(1,0,3)(0,0,0)[0]
# Total fit time: 0.755 seconds
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.69839D+00    |proj g|=  7.15770D-01
#
# At iterate    5    f=  7.68521D+00    |proj g|=  1.24607D-01
#
# At iterate   10    f=  7.68492D+00    |proj g|=  7.51326D-02
#
# At iterate   15    f=  7.68454D+00    |proj g|=  7.97456D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     17     22      1     0     0   6.786D-04   7.685D+00
#   F =   7.6845398113062382
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1751.069, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1708.791, Time=0.01 sec
#  This problem is unconstrained.
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=1070.237, Time=0.04 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=inf, Time=0.06 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=1039.439, Time=0.08 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1701.111, Time=0.01 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.09 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=1042.650, Time=0.08 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=1700.807, Time=0.02 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=inf, Time=0.09 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.07 sec
#
# Best model:  ARIMA(1,0,2)(0,0,0)[0]
# Total fit time: 0.582 seconds
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.70420D+00    |proj g|=  2.41263D+00
#
# At iterate    5    f=  7.68559D+00    |proj g|=  2.65259D-01
#
# At iterate   10    f=  7.66297D+00    |proj g|=  1.83266D-01
#
# At iterate   15    f=  7.66291D+00    |proj g|=  5.06482D-04
#
# At iterate   20    f=  7.66290D+00    |proj g|=  1.05133D-02
#
# At iterate   25    f=  7.66269D+00    |proj g|=  9.38916D-02
#
# At iterate   30    f=  7.62683D+00    |proj g|=  3.70599D+00
#
# At iterate   35    f=  7.61398D+00    |proj g|=  4.86896D+00
#
# At iterate   40    f=  7.60781D+00    |proj g|=  4.86515D-01
#
# At iterate   45    f=  7.60736D+00    |proj g|=  2.35707D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     47     59      1     0     0   2.276D-03   7.607D+00
#   F =   7.6073608125448038
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1757.263, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1715.098, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=inf, Time=0.03 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1707.614, Time=0.02 sec
#  This problem is unconstrained.
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=1059.497, Time=0.05 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.08 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=1058.834, Time=0.07 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=1707.899, Time=0.02 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=inf, Time=0.09 sec
#  ARIMA(1,0,4)(0,0,0)[0]             : AIC=1059.789, Time=0.09 sec
#  ARIMA(0,0,4)(0,0,0)[0]             : AIC=1707.991, Time=0.02 sec
#  ARIMA(2,0,4)(0,0,0)[0]             : AIC=inf, Time=0.10 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=1056.963, Time=0.08 sec
#  ARIMA(0,0,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.09 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.09 sec
#  ARIMA(2,0,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.09 sec
#  ARIMA(1,0,4)(0,0,0)[0] intercept   : AIC=1056.909, Time=0.12 sec
#  ARIMA(0,0,4)(0,0,0)[0] intercept   : AIC=inf, Time=0.11 sec
#  ARIMA(2,0,4)(0,0,0)[0] intercept   : AIC=inf, Time=0.12 sec
#  ARIMA(1,0,5)(0,0,0)[0] intercept   : AIC=1064.510, Time=0.14 sec
#  ARIMA(0,0,5)(0,0,0)[0] intercept   : AIC=inf, Time=0.11 sec
#  ARIMA(2,0,5)(0,0,0)[0] intercept   : AIC=1054.414, Time=0.15 sec
#  ARIMA(3,0,5)(0,0,0)[0] intercept   : AIC=inf, Time=0.18 sec
#  ARIMA(3,0,4)(0,0,0)[0] intercept   : AIC=1053.566, Time=0.15 sec
#  ARIMA(3,0,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.12 sec
#  ARIMA(4,0,4)(0,0,0)[0] intercept   : AIC=1057.301, Time=0.15 sec
#  ARIMA(4,0,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.13 sec
#  ARIMA(4,0,5)(0,0,0)[0] intercept   : AIC=inf, Time=0.16 sec
#  ARIMA(3,0,4)(0,0,0)[0]             : AIC=inf, Time=0.12 sec
#
# Best model:  ARIMA(3,0,4)(0,0,0)[0] intercept
# Total fit time: 2.721 seconds
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.75547D+01    |proj g|=  1.93741D+02
#
# At iterate    5    f=  1.06463D+01    |proj g|=  1.27019D+01
#
# At iterate   10    f=  9.90265D+00    |proj g|=  6.92026D+01
#
# At iterate   15    f=  8.45023D+00    |proj g|=  1.09496D+01
#
# At iterate   20    f=  8.28936D+00    |proj g|=  6.00749D+01
#
# At iterate   25    f=  8.14403D+00    |proj g|=  2.34218D+01
#
# At iterate   30    f=  7.75806D+00    |proj g|=  5.53737D-01
#
# At iterate   35    f=  7.75366D+00    |proj g|=  1.86159D+00
#
# At iterate   40    f=  7.70439D+00    |proj g|=  1.43900D+00
#
# At iterate   45    f=  7.70137D+00    |proj g|=  2.21281D-01
#
# At iterate   50    f=  7.68536D+00    |proj g|=  2.60315D+01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     50     61      1     0     0   2.603D+01   7.685D+00
#   F =   7.6853594194238379
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1755.083, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1712.845, Time=0.01 sec
#  This problem is unconstrained.
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=1087.361, Time=0.04 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=inf, Time=0.06 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=1042.841, Time=0.06 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1705.029, Time=0.01 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.09 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=inf, Time=0.07 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=1705.023, Time=0.02 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=inf, Time=0.08 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.07 sec
#
# Best model:  ARIMA(1,0,2)(0,0,0)[0]
# Total fit time: 0.547 seconds
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.85412D+00    |proj g|=  3.86651D+00
#
# At iterate    5    f=  7.81496D+00    |proj g|=  1.59205D+01
#
# At iterate   10    f=  7.73506D+00    |proj g|=  7.76010D+00
#
# At iterate   15    f=  7.72909D+00    |proj g|=  9.93911D-02
#
# At iterate   20    f=  7.72907D+00    |proj g|=  4.46582D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     20     37      1     0     0   4.466D-03   7.729D+00
#   F =   7.7290651890849480
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1771.171, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1728.867, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=1052.447, Time=0.04 sec
#  This problem is unconstrained.
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=inf, Time=0.06 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=1019.671, Time=0.07 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1721.174, Time=0.01 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.08 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=1022.550, Time=0.08 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=1720.759, Time=0.02 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=inf, Time=0.08 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.08 sec
#
# Best model:  ARIMA(1,0,2)(0,0,0)[0]
# Total fit time: 0.570 seconds
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.82441D+00    |proj g|=  2.28018D+00
#
# At iterate    5    f=  7.71267D+00    |proj g|=  1.63313D+00
#
# At iterate   10    f=  7.70950D+00    |proj g|=  1.84566D-01
#  This problem is unconstrained.
# At iterate   15    f=  7.69336D+00    |proj g|=  1.25143D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     19     22      1     0     0   1.376D-04   7.693D+00
#   F =   7.6925283337787143
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1772.323, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1729.950, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=inf, Time=0.04 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1722.108, Time=0.02 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=971.354, Time=0.06 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.08 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=971.942, Time=0.10 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=1721.588, Time=0.02 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=976.894, Time=0.08 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=inf, Time=0.09 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.09 sec
#
# Best model:  ARIMA(1,0,2)(0,0,0)[0]
# Total fit time: 0.619 seconds
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.23171D+00    |proj g|=  2.52563D+00
#
# At iterate    5    f=  7.22902D+00    |proj g|=  1.79254D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      7     23      1     0     0   1.281D-03   7.229D+00
#   F =   7.2290159170214672
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1715.282, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1673.261, Time=0.01 sec
#  This problem is unconstrained.
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=1099.134, Time=0.05 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=inf, Time=0.06 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=1061.846, Time=0.07 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1666.194, Time=0.01 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.08 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=1063.035, Time=0.07 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=1666.798, Time=0.02 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=inf, Time=0.08 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.07 sec
#
# Best model:  ARIMA(1,0,2)(0,0,0)[0]
# Total fit time: 0.557 seconds
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.18096D+00    |proj g|=  1.12620D+00
#
# At iterate    5    f=  8.13291D+00    |proj g|=  1.51298D-01
#
# At iterate   10    f=  8.08891D+00    |proj g|=  7.75938D-02
#
# At iterate   15    f=  8.08670D+00    |proj g|=  6.03151D-04
#
# At iterate   20    f=  8.08670D+00    |proj g|=  5.56476D-03
#
# At iterate   25    f=  8.08658D+00    |proj g|=  3.42959D-01
#
# At iterate   30    f=  8.07231D+00    |proj g|=  5.69187D+00
#
# At iterate   35    f=  7.93633D+00    |proj g|=  1.21867D+00
#
# At iterate   40    f=  7.93244D+00    |proj g|=  4.71081D-01
#
# At iterate   45    f=  7.93216D+00    |proj g|=  1.90212D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     46     54      1     0     0   1.952D-04   7.932D+00
#   F =   7.9321563446693570
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1737.470, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1695.945, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=1088.182, Time=0.06 sec
#  This problem is unconstrained.
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=inf, Time=0.05 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=1034.884, Time=0.07 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1689.565, Time=0.01 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.10 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=inf, Time=0.07 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=1690.723, Time=0.02 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=inf, Time=0.08 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.07 sec
#
# Best model:  ARIMA(1,0,2)(0,0,0)[0]
# Total fit time: 0.585 seconds
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.53885D+00    |proj g|=  3.82796D+00
#
# At iterate    5    f=  7.52462D+00    |proj g|=  3.57320D+00
#
# At iterate   10    f=  7.50381D+00    |proj g|=  1.27885D+01
#  This problem is unconstrained.
#
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
# At iterate   15    f=  7.49251D+00    |proj g|=  4.56051D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     18     64      2     0     0   3.747D-03   7.492D+00
#   F =   7.4924430812521630
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1757.868, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1716.044, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=1075.748, Time=0.04 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=inf, Time=0.07 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=inf, Time=0.06 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1708.978, Time=0.01 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=inf, Time=0.04 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.09 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.08 sec
#
# Best model:  ARIMA(1,0,1)(0,0,0)[0]
# Total fit time: 0.447 seconds
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.86403D+00    |proj g|=  7.27817D-01
#
# At iterate    5    f=  7.86400D+00    |proj g|=  6.63588D-01
#
# At iterate   10    f=  7.86373D+00    |proj g|=  1.69217D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     13     32      1     0     0   7.769D-04   7.864D+00
#   F =   7.8637327848008916
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1751.553, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1709.829, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=1115.352, Time=0.04 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=inf, Time=0.06 sec
#  This problem is unconstrained.
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=inf, Time=0.06 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1703.203, Time=0.02 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=inf, Time=0.03 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.10 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.07 sec
#
# Best model:  ARIMA(1,0,1)(0,0,0)[0]
# Total fit time: 0.420 seconds
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.19515D+00    |proj g|=  1.84690D+00
#
# At iterate    5    f=  8.14289D+00    |proj g|=  7.96417D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      9     22      1     0     0   4.624D-03   8.142D+00
#   F =   8.1424277600743764
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1728.110, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1685.989, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=1038.095, Time=0.05 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=inf, Time=nan sec
#  This problem is unconstrained.
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=inf, Time=0.05 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1678.423, Time=0.02 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=inf, Time=0.05 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.07 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.07 sec
#
# Best model:  ARIMA(1,0,1)(0,0,0)[0]
# Total fit time: 0.388 seconds
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.86773D+00    |proj g|=  2.70062D-01
#
# At iterate    5    f=  7.86110D+00    |proj g|=  1.40823D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      7     27      1     0     0   1.248D-02   7.861D+00
#   F =   7.8610977991196531
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1721.049, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1678.899, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=1116.385, Time=0.04 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=1071.888, Time=0.08 sec
#  This problem is unconstrained.
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=inf, Time=0.03 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=1075.468, Time=0.09 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.09 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=inf, Time=0.10 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=inf, Time=0.07 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=1063.730, Time=0.10 sec
#  ARIMA(4,0,2)(0,0,0)[0]             : AIC=1061.998, Time=0.13 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=inf, Time=0.11 sec
#  ARIMA(5,0,2)(0,0,0)[0]             : AIC=inf, Time=0.13 sec
#  ARIMA(4,0,3)(0,0,0)[0]             : AIC=inf, Time=0.12 sec
#  ARIMA(3,0,3)(0,0,0)[0]             : AIC=inf, Time=0.10 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=1084.870, Time=0.12 sec
#  ARIMA(5,0,3)(0,0,0)[0]             : AIC=inf, Time=0.13 sec
#  ARIMA(4,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.28 sec
#
# Best model:  ARIMA(4,0,2)(0,0,0)[0]
# Total fit time: 1.767 seconds
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.97851D+01    |proj g|=  1.82940D+03
#
# At iterate    5    f=  5.94966D+01    |proj g|=  1.06976D+03
#
# At iterate   10    f=  5.00696D+01    |proj g|=  1.13354D+04
#
# At iterate   15    f=  9.20686D+00    |proj g|=  1.49976D+03
#
# At iterate   20    f=  8.59448D+00    |proj g|=  3.85806D+01
#
# At iterate   25    f=  8.54461D+00    |proj g|=  6.16438D+02
#
# At iterate   30    f=  8.08716D+00    |proj g|=  1.85144D+02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     34     52      1     0     0   1.466D+01   8.048D+00
#   F =   8.0476952522882019
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1763.490, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1720.974, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=1134.845, Time=0.04 sec
#  This problem is unconstrained.
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=inf, Time=0.08 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=inf, Time=0.06 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1712.546, Time=0.01 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=inf, Time=0.05 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.07 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=1257.556, Time=0.10 sec
#
# Best model:  ARIMA(1,0,1)(0,0,0)[0]
# Total fit time: 0.469 seconds
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.55858D+00    |proj g|=  1.48959D+00
#
# At iterate    5    f=  8.50888D+00    |proj g|=  9.23593D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6     10      1     0     0   2.194D-04   8.509D+00
#   F =   8.5088834374914804
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1760.747, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1718.666, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=1069.026, Time=0.04 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=inf, Time=0.05 sec
#  This problem is unconstrained.
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=1054.630, Time=0.07 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1711.332, Time=0.02 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=1055.239, Time=0.08 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=inf, Time=0.09 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=1711.197, Time=0.02 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=inf, Time=0.09 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=1051.280, Time=0.05 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.05 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=1066.636, Time=0.06 sec
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.09 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=1055.758, Time=0.09 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.02 sec
#  ARIMA(0,0,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.08 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=nan sec
#  ARIMA(2,0,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.09 sec
#
# Best model:  ARIMA(1,0,2)(0,0,0)[0] intercept
# Total fit time: 1.107 seconds
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.90879D+00    |proj g|=  1.54271D+00
#
# At iterate    5    f=  7.87948D+00    |proj g|=  3.95445D-01
#
# At iterate   10    f=  7.85456D+00    |proj g|=  3.60129D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     12     58      2     0     0   2.041D-02   7.855D+00
#   F =   7.8545614375706441
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1776.221, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.02 sec
#  This problem is unconstrained.
#
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1733.766, Time=0.02 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=1032.761, Time=0.05 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=inf, Time=0.07 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=1025.750, Time=0.06 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1725.757, Time=0.01 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=1021.749, Time=0.09 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=inf, Time=0.11 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=inf, Time=0.09 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=inf, Time=0.07 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=inf, Time=0.09 sec
#  ARIMA(3,0,3)(0,0,0)[0]             : AIC=1034.482, Time=0.06 sec
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.10 sec
#
# Best model:  ARIMA(2,0,2)(0,0,0)[0]
# Total fit time: 0.857 seconds
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.00405D+00    |proj g|=  1.74595D+01
#
# At iterate    5    f=  7.58605D+00    |proj g|=  1.84117D+00
#
# At iterate   10    f=  7.58456D+00    |proj g|=  1.09294D+00
#
# At iterate   15    f=  7.58025D+00    |proj g|=  1.74207D+01
#
# At iterate   20    f=  7.55436D+00    |proj g|=  3.31778D+00
#
# At iterate   25    f=  7.55412D+00    |proj g|=  2.87621D-01
#
# At iterate   30    f=  7.55179D+00    |proj g|=  3.84904D+00
#
# At iterate   35    f=  7.54817D+00    |proj g|=  2.73711D-01
#
# At iterate   40    f=  7.54634D+00    |proj g|=  2.09327D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     41     65      1     0     0   2.093D-02   7.546D+00
#   F =   7.5463375401727424
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1717.690, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1676.326, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=inf, Time=0.03 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1669.933, Time=0.02 sec
#  This problem is unconstrained.
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=1047.093, Time=0.10 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.06 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=1034.123, Time=0.08 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=1671.152, Time=0.02 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=inf, Time=0.10 sec
#  ARIMA(1,0,4)(0,0,0)[0]             : AIC=1015.181, Time=0.09 sec
#  ARIMA(0,0,4)(0,0,0)[0]             : AIC=1673.265, Time=0.02 sec
#  ARIMA(2,0,4)(0,0,0)[0]             : AIC=inf, Time=0.13 sec
#  ARIMA(1,0,5)(0,0,0)[0]             : AIC=1005.058, Time=0.11 sec
#  ARIMA(0,0,5)(0,0,0)[0]             : AIC=1677.206, Time=0.03 sec
#  ARIMA(2,0,5)(0,0,0)[0]             : AIC=inf, Time=0.13 sec
#  ARIMA(1,0,5)(0,0,0)[0] intercept   : AIC=inf, Time=0.12 sec
#
# Best model:  ARIMA(1,0,5)(0,0,0)[0]
# Total fit time: 1.076 seconds
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.67975D+00    |proj g|=  5.22058D+00
#
# At iterate    5    f=  7.56997D+00    |proj g|=  6.72744D+00
#
# At iterate   10    f=  7.47790D+00    |proj g|=  1.84998D+00
#
# At iterate   15    f=  7.38217D+00    |proj g|=  1.81374D-01
#
# At iterate   20    f=  7.37774D+00    |proj g|=  3.06789D-01
#
# At iterate   25    f=  7.37753D+00    |proj g|=  2.96514D-01
#
# At iterate   30    f=  7.37648D+00    |proj g|=  7.38221D-02
#  This problem is unconstrained.
# At iterate   35    f=  7.37645D+00    |proj g|=  7.93438D-03
#
# At iterate   40    f=  7.37622D+00    |proj g|=  1.58812D-01
#
# At iterate   45    f=  7.37545D+00    |proj g|=  1.22247D-01
#
# At iterate   50    f=  7.37515D+00    |proj g|=  1.88765D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     60      1     0     0   1.888D-03   7.375D+00
#   F =   7.3751505752126469
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1742.826, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1700.709, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=inf, Time=0.03 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1693.105, Time=0.02 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=995.756, Time=0.05 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.09 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=996.789, Time=0.05 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=1692.791, Time=0.02 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=inf, Time=nan sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=inf, Time=0.09 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.08 sec
#
# Best model:  ARIMA(1,0,2)(0,0,0)[0]
# Total fit time: 0.527 seconds
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.37693D+00    |proj g|=  3.39821D-01
#
# At iterate    5    f=  7.36334D+00    |proj g|=  2.10780D-01
#
# At iterate   10    f=  7.35433D+00    |proj g|=  1.25536D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     12     18      1     0     0   3.336D-04   7.354D+00
#   F =   7.3543335567545434
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1771.304, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1728.812, Time=0.01 sec
#  This problem is unconstrained.
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=1153.577, Time=0.06 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=inf, Time=0.07 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=inf, Time=0.05 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1720.550, Time=0.06 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=inf, Time=0.04 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.09 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.07 sec
#
# Best model:  ARIMA(1,0,1)(0,0,0)[0]
# Total fit time: 0.467 seconds
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.65543D+00    |proj g|=  1.21910D+00
#
# At iterate    5    f=  8.63767D+00    |proj g|=  8.59833D+00
#
# At iterate   10    f=  8.62887D+00    |proj g|=  3.41573D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     12     31      1     0     0   4.314D-04   8.629D+00
#   F =   8.6288749070649242
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Performing stepwise search to minimize aic
#  This problem is unconstrained.
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1705.332, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1663.589, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=1133.270, Time=0.05 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=inf, Time=nan sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=1079.861, Time=0.09 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1656.889, Time=0.02 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.07 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=1068.693, Time=0.08 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=1657.861, Time=0.02 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=inf, Time=0.10 sec
#  ARIMA(1,0,4)(0,0,0)[0]             : AIC=1054.853, Time=0.10 sec
#  ARIMA(0,0,4)(0,0,0)[0]             : AIC=1661.322, Time=0.02 sec
#  ARIMA(2,0,4)(0,0,0)[0]             : AIC=inf, Time=0.11 sec
#  ARIMA(1,0,5)(0,0,0)[0]             : AIC=1049.863, Time=0.10 sec
#  ARIMA(0,0,5)(0,0,0)[0]             : AIC=1665.517, Time=0.03 sec
#  ARIMA(2,0,5)(0,0,0)[0]             : AIC=1055.285, Time=0.12 sec
#  ARIMA(1,0,5)(0,0,0)[0] intercept   : AIC=1061.021, Time=0.12 sec
#
# Best model:  ARIMA(1,0,5)(0,0,0)[0]
# Total fit time: 1.141 seconds
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.48153D+00    |proj g|=  5.00387D-01
#
# At iterate    5    f=  7.46404D+00    |proj g|=  1.20228D-01
#
# At iterate   10    f=  7.45640D+00    |proj g|=  9.86170D-02
#
# At iterate   15    f=  7.45368D+00    |proj g|=  1.86094D-03
#
# At iterate   20    f=  7.45365D+00    |proj g|=  5.83865D-03
#
# At iterate   25    f=  7.45364D+00    |proj g|=  1.20651D-03
#
# At iterate   30    f=  7.45363D+00    |proj g|=  3.08769D-03
#  This problem is unconstrained.
# At iterate   35    f=  7.45350D+00    |proj g|=  1.60271D-01
#
# At iterate   40    f=  7.45306D+00    |proj g|=  5.08192D-02
#
# At iterate   45    f=  7.45278D+00    |proj g|=  1.00438D-01
#
# At iterate   50    f=  7.45240D+00    |proj g|=  3.31658D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     58      1     0     0   3.317D-02   7.452D+00
#   F =   7.4523971019527089
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1698.308, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1656.859, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=1107.143, Time=0.06 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=inf, Time=0.08 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=1067.719, Time=0.07 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1650.469, Time=0.01 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.09 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=inf, Time=0.07 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=1651.671, Time=0.02 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=inf, Time=0.08 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.07 sec
#
# Best model:  ARIMA(1,0,2)(0,0,0)[0]
# Total fit time: 0.596 seconds
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.88969D+00    |proj g|=  1.33452D+00
#
# At iterate    5    f=  7.87129D+00    |proj g|=  1.51746D-01
#
# At iterate   10    f=  7.86277D+00    |proj g|=  1.30572D+00
#
# At iterate   15    f=  7.80844D+00    |proj g|=  5.04728D-02
#
# At iterate   20    f=  7.80583D+00    |proj g|=  7.17502D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     22     31      1     0     0   5.906D-04   7.806D+00
#   F =   7.8058249292844417
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.

# %%
# Sorting our 3 year ROI forecast for zipcodes into descending order
sort_orders = sorted(zip_predictions.items(), key=lambda x: x[1], reverse=True)

sorted_forecast_3yr = {}
for i in sort_orders:
	sorted_forecast_3yr[i[0]] = i[1]

#Selecting only the Top 5 Zips
top_5_zipcodes = list(sorted_forecast_3yr.items())[:5]

fig, ax = plt.subplots(figsize=(18,12))

x_labels = [top_5_zipcodes[0][0],top_5_zipcodes[1][0],top_5_zipcodes[2][0],
            top_5_zipcodes[3][0],top_5_zipcodes[4][0]]
x = [1,2,3,4,5]
y = [top_5_zipcodes[0][1],top_5_zipcodes[1][1],top_5_zipcodes[2][1],
     top_5_zipcodes[3][1],top_5_zipcodes[4][1]]

ax.bar(x, y, color='mediumslateblue')
remaining_zipcodes = list(sorted_forecast_3yr.items())[5:]
median_ROI_other_zips = remaining_zipcodes[5][1]
ax.axhline(y=median_ROI_other_zips,label = 'Median ROI for remaining Zips')
ax.set_xticks(x)
ax.set_xticklabels(x_labels)
ax.set_yticks([(a/100) for a in list(range(0,75,5))])
ax.set_yticklabels([str(a)+'%' for a in list(range(0,75,5))])
ax.set_title('Top 5 Recommendations', fontsize=20)
ax.set_ylabel('Average ROI', fontsize=20)
ax.set_xlabel('Zipcodes',fontsize=20)
ax.legend(prop={'size': 15});

# %% [markdown]
# # Conclusion

# %%
print(f'The Highest Growing Zipcode: {list(sorted_forecast_3yr.items())[0][0]} is expected to grow by {round((list(sorted_forecast_3yr.items())[0][1])*100,2)}%')
print(f'The Second Highest Growing Zipcode: {list(sorted_forecast_3yr.items())[1][0]} is expected to grow by {round((list(sorted_forecast_3yr.items())[1][1])*100,2)}%')
print(f'The Third Highest Growing Zipcode: {list(sorted_forecast_3yr.items())[2][0]} is expected to grow by {round((list(sorted_forecast_3yr.items())[2][1])*100,2)}%')
print(f'The Fourth Highest Growing Zipcode: {list(sorted_forecast_3yr.items())[3][0]} is expected to grow by {round((list(sorted_forecast_3yr.items())[3][1])*100,2)}%')
print(f'The Fifth Highest Growing Zipcode: {list(sorted_forecast_3yr.items())[4][0]} is expected to grow by {round((list(sorted_forecast_3yr.items())[4][1])*100,2)}%')
# Out:
# The Highest Growing Zipcode: 33602 is expected to grow by 50.17%
# The Second Highest Growing Zipcode: 86334 is expected to grow by 49.83%
# The Third Highest Growing Zipcode: 30316 is expected to grow by 46.32%
# The Fourth Highest Growing Zipcode: 32233 is expected to grow by 46.19%
# The Fifth Highest Growing Zipcode: 19125 is expected to grow by 38.1%

# %%
recommended_zips = pd.DataFrame([a for a in sorted_forecast_3yr.keys()][:5])
recommended_zips.columns = ['RegionName']
final_zips_map = pd.merge(recommended_zips, zip_long_lat, how="left", on=["RegionName"])
print(final_zips_map)
# Out:
#    RegionName  Latitude  Longitude
# 0       33602  27.94946  -82.46118
# 1       86334  34.94867 -112.54443
# 2       30316  33.71759  -84.33225
# 3       32233  30.36143  -81.42642
# 4       19125  39.97641  -75.12217

# %%
geometry = [Point(xy) for xy in zip(final_zips_map['Longitude'], final_zips_map['Latitude'])] #create Points
geo_df = gpd.GeoDataFrame(final_zips_map, 
                          crs = crs, 
                          geometry = geometry) #define the geometry df

#plot the data
fig, ax = plt.subplots(figsize = (10,10))
us49.to_crs(epsg=4326).plot(ax=ax)
sns.scatterplot(x="Longitude", y="Latitude",data=final_zips_map, ax=ax)
ax.set_title('Distribution of Top 5 Most Profitable Zip Codes');
